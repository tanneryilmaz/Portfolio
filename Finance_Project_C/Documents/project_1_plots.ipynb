# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nfl_wealth = np.array([-24100, -164381, -130388, -96978, -64032, -31451, 847, 32934, 64867, 96693, 128453, 160182, 191908, 223654, 225442, 287287, 319205, 351208, 383306, 415508, 447823, 480255, 512812, 545499, 578319, 611278, 644378, 677622, 711015, 744558, 778254, 812106, 846116, 880284, 914604, 949090, 983744, 1018568, 1053562, 1088730, 1124072])
fl_wealth = np.array([-24100, 1598, 27330, 53306, -85082, -47864, -9875, 29038, 69023, 110224, 152784, 196846, 242555, 290059, 339512, 391072, 444908, 501194, 560115, 621738, 686366, 754279, 825707, 900896, 980109, 1063628, 1151754, 1244811, 1343142, 1447117, 1557132, 1673608, 1796999, 1927789, 2066494, 2213670, 2369910, 2535847, 2712160, 2899577, 3098874])
time = np.linspace(0, 40, 41)

plt.figure(1)
plt.plot(time, nfl_wealth, 'ro', label = "nfl")

plt.xlabel('Time (Years)')
plt.ylabel('Wealth (Dollars)')
plt.suptitle('Wealth vs. Time - NFL')
plt.savefig('Wealth_Plot_NFL')
plt.legend(loc='upper left')

plt.figure(2)
plt.plot(time, fl_wealth, 'bo', label = "fl")
plt.savefig('Wealth_Plot_FL')

plt.xlabel('Time (Years)')
plt.ylabel('Wealth (Dollars)')
plt.suptitle('Wealth vs. Time - FL')
plt.savefig('Wealth_Plot_FL')

plt.legend(loc='upper left')
plt.show()
